# %% [markdown]
# ## import

# %%
# !pip install torch transformers datasets accelerate scikit-learn
# Out:
# Collecting torch
#   Using cached torch-2.9.0-cp310-cp310-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: transformers in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (4.57.1)
# Collecting datasets
#   Using cached datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Collecting accelerate
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=21.0.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from datasets) (0.70.18)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Using cached aiohttp-3.13.2-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: anyio in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: psutil in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: scipy>=1.8.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in g:\マイドライブ\研究\s2orcranker\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached torch-2.9.0-cp310-cp310-win_amd64.whl (109.3 MB)
# Using cached datasets-4.4.1-py3-none-any.whl (511 kB)
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Using cached aiohttp-3.13.2-cp310-cp310-win_amd64.whl (455 kB)
# Installing collected packages: torch, scikit-learn, aiohttp, accelerate, datasets
#
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
#    ---------------------------------------- 0/5 [torch]
# ...
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    -------- ------------------------------- 1/5 [scikit-learn]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ---------------- ----------------------- 2/5 [aiohttp]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    ------------------------ --------------- 3/5 [accelerate]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    -------------------------------- ------- 4/5 [datasets]
#    ---------------------------------------- 5/5 [datasets]
#
# Successfully installed accelerate-1.11.0 aiohttp-3.13.2 datasets-4.4.1 scikit-learn-1.7.2 torch-2.9.0

# %%
# !nvidia-smi
# Out:
# Sun Nov  9 05:59:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.52                 Driver Version: 576.52         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   47C    P8            N/A  /  120W |    1295MiB /   8188MiB |     40%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2096    C+G   ...ef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A            2716    C+G   ...em_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A            6672    C+G   ....0.3595.53\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            8132    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            8940    C+G   ...0.283.1.4\OverwolfBrowser.exe      N/A      |
# |    0   N/A  N/A           10732    C+G   ...s (x86)\Overwolf\Overwolf.exe      N/A      |
# |    0   N/A  N/A           11300    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           11696    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           11808    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           12364    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           12380    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           12940    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           12960    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           13332    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           13444    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           13496    C+G   ...8bbwe\Microsoft.CmdPal.UI.exe      N/A      |
# |    0   N/A  N/A           15876    C+G   ....0.3595.53\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           17756    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           19008    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           19344    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           19528    C+G   ...cord\app-1.0.9213\Discord.exe      N/A      |
# |    0   N/A  N/A           19732    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20304    C+G   ...s\PowerToys.ColorPickerUI.exe      N/A      |
# |    0   N/A  N/A           20424    C+G   ...Toys\PowerToys.FancyZones.exe      N/A      |
# |    0   N/A  N/A           20828    C+G   ...UI3Apps\PowerToys.Peek.UI.exe      N/A      |
# |    0   N/A  N/A           21176    C+G   ...s\PowerToys.PowerLauncher.exe      N/A      |
# |    0   N/A  N/A           21396    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22968    C+G   ...SnippingTool\SnippingTool.exe      N/A      |
# |    0   N/A  N/A           23504    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import pandas as pd
import os
import numpy as np
import torch
import torch.nn as nn
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModel, BertPreTrainedModel, TrainingArguments, Trainer
from transformers.modeling_outputs import SequenceClassifierOutput
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import accelerate

# --- 1. GPUの確認 ---
if torch.cuda.is_available():
    print(f"✅ GPU is available. Device: {torch.cuda.get_device_name(0)}")
    device = torch.device("cuda")
else:
    print("⚠️ GPU not found. Running on CPU.")
    device = torch.device("cpu")
# Out:
# ⚠️ GPU not found. Running on CPU.

# %% [markdown]
# ## setting

# %% [markdown]
# ## モデル

# %% [markdown]
# ## データロードとトークナイズ

# %% [markdown]
# ## モデルのロードと訓練設定

# %% [markdown]
# ## 訓練開始

# %% [markdown]
# ## モデルの保存
